# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df_wiki = pd.read_csv("quest2_wiki_daily.csv") 
df_wiki
# Out:
#      Unnamed: 0  Alternative_für_Deutschland
# 0    2024-11-01                         1223
# 1    2024-11-02                         1323
# 2    2024-11-03                         1309
# 3    2024-11-04                         1601
# 4    2024-11-05                         1769
# ..          ...                          ...
# 115  2025-02-24                        46538
# 116  2025-02-25                        19592
# 117  2025-02-26                        14399
# 118  2025-02-27                         8108
# 119  2025-02-28                         6006
#
# [120 rows x 2 columns]

# %%
df_videos = pd.read_csv("quest2_yt_daily.csv")
df_videos
# Out:
#                   Published At  Number of Videos
# 0    2024-11-01 00:00:00+00:00                 7
# 1    2024-11-02 00:00:00+00:00                 3
# 2    2024-11-03 00:00:00+00:00                 9
# 3    2024-11-04 00:00:00+00:00                 4
# 4    2024-11-05 00:00:00+00:00                 1
# ..                         ...               ...
# 115  2025-02-24 00:00:00+00:00                24
# 116  2025-02-25 00:00:00+00:00                13
# 117  2025-02-26 00:00:00+00:00                 9
# 118  2025-02-27 00:00:00+00:00                10
# 119  2025-02-28 00:00:00+00:00                15
#
# [120 rows x 2 columns]

# %%
# Rename columns for clarity
df_wiki = df_wiki.rename(columns={'Unnamed: 0': 'Published At', 'Alternative_für_Deutschland' : 'Wikipedia Pageviews'})

# Ensure both columns are datetime
df_videos['Published At'] = pd.to_datetime(df_videos['Published At'], errors='coerce')
df_wiki['Published At'] = pd.to_datetime(df_wiki['Published At'], errors='coerce')

# Remove timezone from df_videos if it exists
if df_videos['Published At'].dt.tz is not None:
    df_videos['Published At'] = df_videos['Published At'].dt.tz_localize(None)


# Merge on 'Published At'
df_merged = pd.merge(df_videos, df_wiki, on='Published At', how='inner')


df_merged
# Out:
#     Published At  Number of Videos  Wikipedia Pageviews
# 0     2024-11-01                 7                 1223
# 1     2024-11-02                 3                 1323
# 2     2024-11-03                 9                 1309
# 3     2024-11-04                 4                 1601
# 4     2024-11-05                 1                 1769
# ..           ...               ...                  ...
# 115   2025-02-24                24                46538
# 116   2025-02-25                13                19592
# 117   2025-02-26                 9                14399
# 118   2025-02-27                10                 8108
# 119   2025-02-28                15                 6006
#
# [120 rows x 3 columns]

# %%
def normalize_to_relative(df, columns):
    """
    Convert the specified columns in a DataFrame to relative values
    (each value divided by the total of its column).

    Parameters:
        df (pd.DataFrame): Input DataFrame
        columns (list): List of column names to normalize

    Returns:
        pd.DataFrame: DataFrame with normalized columns
    """
    df_relative = df.copy()
    for col in columns:
        total = df_relative[col].sum()
        df_relative[col] = df_relative[col] / total*100
    return df_relative

# Example usage:
columns_to_normalize = ['Number of Videos', 'Wikipedia Pageviews']
df_relative = normalize_to_relative(df_merged, columns_to_normalize)

# Make 'Published At' the index

df_relative.to_csv('AfD_combined_daily_relative.csv')

df_relative
# Out:
#     Published At  Number of Videos  Wikipedia Pageviews
# 0     2024-11-01          0.620018             0.165349
# 1     2024-11-02          0.265722             0.178869
# 2     2024-11-03          0.797166             0.176976
# 3     2024-11-04          0.354296             0.216454
# 4     2024-11-05          0.088574             0.239167
# ..           ...               ...                  ...
# 115   2025-02-24          2.125775             6.291903
# 116   2025-02-25          1.151461             2.648824
# 117   2025-02-26          0.797166             1.946734
# 118   2025-02-27          0.885740             1.096196
# 119   2025-02-28          1.328609             0.812007
#
# [120 rows x 3 columns]

# %%
plot2 = df_relative.plot(
    kind='scatter',
    x='Number of Videos',
    y='Wikipedia Pageviews',
    figsize=(8,6),
    title='Correlation: Videos vs Wikipedia Pageviews'
)
plot2
# Out:
# <Axes: title={'center': 'Correlation: Videos vs Wikipedia Pageviews'}, xlabel='Number of Videos', ylabel='Wikipedia Pageviews'>

# %%
plot = df_relative.plot(
    kind='bar',
    title= 'WikipediaPage Views and Youtube Video Uploads in Percent'
)
for i, label in enumerate(plot.get_xticklabels()):
    if i % 7 != 0:   # hide every second label
        label.set_visible(False)
plt.show()

# %%
corr = df_relative['Number of Videos'].corr(df_relative['Wikipedia Pageviews'])
print(f"Pearson correlation: {corr:.2f}")
# Out:
# Pearson correlation: 0.49

# %%
import numpy as np

x = df_relative['Number of Videos']
y = df_relative['Wikipedia Pageviews']

plt.figure(figsize=(8,6))
plt.scatter(x, y)
m, b = np.polyfit(x, y, 1)  # lineare Regression
plt.plot(x, m*x + b, color='black', label='Trendline')
plt.xlabel('Number of Videos (relative)')
plt.ylabel('Wikipedia Pageviews (relative)')
plt.title('Correlation: Videos vs Wikipedia Pageviews')
plt.legend()
plt.grid(True)
plt.show()

# %%
import json 

json_str = df_relative.to_json(orient="records", indent=2, force_ascii=False)

with open("AfD_combined_daily_relative.json", "w", encoding="utf-8") as f:
    f.write(json_str)

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\asus\scoop\persist\python310\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\asus\appdata\roaming\python\python310\site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\asus\scoop\persist\python310\lib\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\asus\scoop\persist\python310\lib\site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\asus\scoop\persist\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asus\scoop\persist\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: pillow>=8 in c:\users\asus\scoop\persist\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\scoop\persist\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\scoop\persist\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\scoop\persist\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\asus\scoop\persist\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\scoop\persist\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\scoop\persist\python310\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\scoop\persist\python310\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\asus\scoop\persist\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import seaborn as sns

sns.set(style="ticks")

# Show the results of a linear regression
sns.lmplot(x="Number of Videos", y="Wikipedia Pageviews", data=df_relative)

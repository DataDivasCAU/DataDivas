# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from mwviews.api import PageviewsClient

# Sends a descriptive User-Agent header with every request
p = PageviewsClient(user_agent="<person@organization.org> Selfie, Cat, and Dog analysis")

# %%
quest1 = p.article_views('de.wikipedia', ['Alternative für Deutschland', 'Alice Weidel', 'Tino Chrupalla'])
quest1
# Out:
# defaultdict(dict,
#             {datetime.datetime(2025, 8, 12, 0, 0): {'Alternative_für_Deutschland': 1789,
#               'Alice_Weidel': 1766,
#               'Tino_Chrupalla': 1332},
#              datetime.datetime(2025, 8, 13, 0, 0): {'Alternative_für_Deutschland': 1530,
#               'Alice_Weidel': 1852,
#               'Tino_Chrupalla': 889},
#              datetime.datetime(2025, 8, 14, 0, 0): {'Alternative_für_Deutschland': 1733,
#               'Alice_Weidel': 1872,
#               'Tino_Chrupalla': 822},
#              datetime.datetime(2025, 8, 15, 0, 0): {'Alternative_für_Deutschland': 1518,
#               'Alice_Weidel': 1632,
#               'Tino_Chrupalla': 637},
#              datetime.datetime(2025, 8, 16, 0, 0): {'Alternative_für_Deutschland': 1253,
#               'Alice_Weidel': 1720,
#               'Tino_Chrupalla': 544},
#              datetime.datetime(2025, 8, 17, 0, 0): {'Alternative_für_Deutschland': 1466,
#               'Alice_Weidel': 2787,
#               'Tino_Chrupalla': 755},
#              datetime.datetime(2025, 8, 18, 0, 0): {'Alternative_für_Deutschland': 1567,
#               'Alice_Weidel': 2996,
#               'Tino_Chrupalla': 759},
#              datetime.datetime(2025, 8, 19, 0, 0): {'Alternative_für_Deutschland': 2096,
#               'Alice_Weidel': 2873,
#               'Tino_Chrupalla': 766},
#              datetime.datetime(2025, 8, 20, 0, 0): {'Alternative_für_Deutschland': 1772,
#               'Alice_Weidel': 1929,
#               'Tino_Chrupalla': 697},
#              datetime.datetime(2025, 8, 21, 0, 0): {'Alternative_für_Deutschland': 1595,
#               'Alice_Weidel': 1874,
#               'Tino_Chrupalla': 737},
#              datetime.datetime(2025, 8, 22, 0, 0): {'Alternative_für_Deutschland': 1378,
#               'Alice_Weidel': 1883,
#               'Tino_Chrupalla': 573},
#              datetime.datetime(2025, 8, 23, 0, 0): {'Alternative_für_Deutschland': 1289,
#               'Alice_Weidel': 1533,
#               'Tino_Chrupalla': 512},
#              datetime.datetime(2025, 8, 24, 0, 0): {'Alternative_für_Deutschland': 1460,
#               'Alice_Weidel': 1646,
#               'Tino_Chrupalla': 617},
#              datetime.datetime(2025, 8, 25, 0, 0): {'Alternative_für_Deutschland': 1529,
#               'Alice_Weidel': 1695,
#               'Tino_Chrupalla': 650},
#              datetime.datetime(2025, 8, 26, 0, 0): {'Alternative_für_Deutschland': 1479,
#               'Alice_Weidel': 1561,
#               'Tino_Chrupalla': 647},
#              datetime.datetime(2025, 8, 27, 0, 0): {'Alternative_für_Deutschland': 1506,
#               'Alice_Weidel': 1527,
#               'Tino_Chrupalla': 588},
#              datetime.datetime(2025, 8, 28, 0, 0): {'Alternative_für_Deutschland': 1628,
#               'Alice_Weidel': 1844,
#               'Tino_Chrupalla': 555},
#              datetime.datetime(2025, 8, 29, 0, 0): {'Alternative_für_Deutschland': 1492,
#               'Alice_Weidel': 1889,
#               'Tino_Chrupalla': 542},
#              datetime.datetime(2025, 8, 30, 0, 0): {'Alternative_für_Deutschland': 1379,
#               'Alice_Weidel': 1587,
#               'Tino_Chrupalla': 499},
#              datetime.datetime(2025, 8, 31, 0, 0): {'Alternative_für_Deutschland': 1547,
#               'Alice_Weidel': 1634,
#               'Tino_Chrupalla': 535},
#              datetime.datetime(2025, 9, 1, 0, 0): {'Alternative_für_Deutschland': 1466,
#               'Alice_Weidel': 1504,
#               'Tino_Chrupalla': 505},
#              datetime.datetime(2025, 9, 2, 0, 0): {'Alternative_für_Deutschland': 1666,
#               'Alice_Weidel': 1677,
#               'Tino_Chrupalla': 596},
#              datetime.datetime(2025, 9, 3, 0, 0): {'Alternative_für_Deutschland': 1640,
#               'Alice_Weidel': 1860,
#               'Tino_Chrupalla': 737},
#              datetime.datetime(2025, 9, 4, 0, 0): {'Alternative_für_Deutschland': 2054,
#               'Alice_Weidel': 1942,
#               'Tino_Chrupalla': 756},
#              datetime.datetime(2025, 9, 5, 0, 0): {'Alternative_für_Deutschland': 2094,
#               'Alice_Weidel': 1996,
#               'Tino_Chrupalla': 696},
#              datetime.datetime(2025, 9, 6, 0, 0): {'Alternative_für_Deutschland': 1815,
#               'Alice_Weidel': 1728,
#               'Tino_Chrupalla': 529},
#              datetime.datetime(2025, 9, 7, 0, 0): {'Alternative_für_Deutschland': 1961,
#               'Alice_Weidel': 2088,
#               'Tino_Chrupalla': 609},
#              datetime.datetime(2025, 9, 8, 0, 0): {'Alternative_für_Deutschland': 1986,
#               'Alice_Weidel': 1985,
#               'Tino_Chrupalla': 855},
#              datetime.datetime(2025, 9, 9, 0, 0): {'Alternative_für_Deutschland': 1941,
#               'Alice_Weidel': 2138,
#               'Tino_Chrupalla': 970},
#              datetime.datetime(2025, 9, 10, 0, 0): {'Alternative_für_Deutschland': 1763,
#               'Alice_Weidel': 1773,
#               'Tino_Chrupalla': 793},
#              datetime.datetime(2025, 9, 11, 0, 0): {'Alternative_für_Deutschland': None,
#               'Alice_Weidel': None,
#               'Tino_Chrupalla': None}})

# %%
df = pd.DataFrame(quest1)
df
# Out:
#                              2025-08-12  2025-08-13  2025-08-14  2025-08-15  \
# Alternative_für_Deutschland        1789        1530        1733        1518
# Alice_Weidel                       1766        1852        1872        1632
# Tino_Chrupalla                     1332         889         822         637
#
#                              2025-08-16  2025-08-17  2025-08-18  2025-08-19  \
# Alternative_für_Deutschland        1253        1466        1567        2096
# Alice_Weidel                       1720        2787        2996        2873
# Tino_Chrupalla                      544         755         759         766
#
#                              2025-08-20  2025-08-21  ...  2025-09-02  \
# Alternative_für_Deutschland        1772        1595  ...        1666
# Alice_Weidel                       1929        1874  ...        1677
# Tino_Chrupalla                      697         737  ...         596
#
#                              2025-09-03  2025-09-04  2025-09-05  2025-09-06  \
# Alternative_für_Deutschland        1640        2054        2094        1815
# Alice_Weidel                       1860        1942        1996        1728
# Tino_Chrupalla                      737         756         696         529
#
#                              2025-09-07  2025-09-08  2025-09-09  2025-09-10  \
# Alternative_für_Deutschland        1961        1986        1941        1763
# Alice_Weidel                       2088        1985        2138        1773
# Tino_Chrupalla                      609         855         970         793
#
#                              2025-09-11
# Alternative_für_Deutschland        None
# Alice_Weidel                       None
# Tino_Chrupalla                     None
#
# [3 rows x 31 columns]

# %%
df1_2 = df.transpose()
df1_2
# Out:
#            Alternative_für_Deutschland Alice_Weidel Tino_Chrupalla
# 2025-08-12                        1789         1766           1332
# 2025-08-13                        1530         1852            889
# 2025-08-14                        1733         1872            822
# 2025-08-15                        1518         1632            637
# 2025-08-16                        1253         1720            544
# 2025-08-17                        1466         2787            755
# 2025-08-18                        1567         2996            759
# 2025-08-19                        2096         2873            766
# 2025-08-20                        1772         1929            697
# 2025-08-21                        1595         1874            737
# 2025-08-22                        1378         1883            573
# 2025-08-23                        1289         1533            512
# 2025-08-24                        1460         1646            617
# 2025-08-25                        1529         1695            650
# 2025-08-26                        1479         1561            647
# 2025-08-27                        1506         1527            588
# 2025-08-28                        1628         1844            555
# 2025-08-29                        1492         1889            542
# 2025-08-30                        1379         1587            499
# 2025-08-31                        1547         1634            535
# 2025-09-01                        1466         1504            505
# 2025-09-02                        1666         1677            596
# 2025-09-03                        1640         1860            737
# 2025-09-04                        2054         1942            756
# 2025-09-05                        2094         1996            696
# 2025-09-06                        1815         1728            529
# 2025-09-07                        1961         2088            609
# 2025-09-08                        1986         1985            855
# 2025-09-09                        1941         2138            970
# 2025-09-10                        1763         1773            793
# 2025-09-11                        None         None           None

# %%
plot = df1_2.plot(title="Page Views the last 30 Days")
plot
# Feel free to add your own features in pull requests!
# Out:
# <Axes: title={'center': 'Page Views the last 30 Days'}>

# %%
quest2 = p.project_views(['ro.wikipedia', 'de.wikipedia', 'commons.wikimedia'])

# %%
quest3 = p.top_articles('en.wikipedia', limit=10)

# %%
quest4 = p.top_by_country('en.wikipedia', limit=10)

# %%
quest5 = p.top_per_country('in', limit=10)

# %%
quest6 = p.article_views('de.wikipedia', ['Alternative für Deutschland'], granularity='daily', start='20241101', end='20250228')


df6 = pd.DataFrame(quest6)
df6
# Out:
#                              2024-11-01  2024-11-02  2024-11-03  2024-11-04  \
# Alternative_für_Deutschland        1223        1323        1309        1601
#
#                              2024-11-05  2024-11-06  2024-11-07  2024-11-08  \
# Alternative_für_Deutschland        1769        3024        4722        3550
#
#                              2024-11-09  2024-11-10  ...  2025-02-19  \
# Alternative_für_Deutschland        2612        2679  ...       12826
#
#                              2025-02-20  2025-02-21  2025-02-22  2025-02-23  \
# Alternative_für_Deutschland       11416       10512       12667       60913
#
#                              2025-02-24  2025-02-25  2025-02-26  2025-02-27  \
# Alternative_für_Deutschland       46538       19592       14399        8108
#
#                              2025-02-28
# Alternative_für_Deutschland        6006
#
# [1 rows x 120 columns]

# %%
df6_2 = df6.transpose()
df6_2
# Out:
#             Alternative_für_Deutschland
# 2024-11-01                         1223
# 2024-11-02                         1323
# 2024-11-03                         1309
# 2024-11-04                         1601
# 2024-11-05                         1769
# ...                                 ...
# 2025-02-24                        46538
# 2025-02-25                        19592
# 2025-02-26                        14399
# 2025-02-27                         8108
# 2025-02-28                         6006
#
# [120 rows x 1 columns]

# %%
df6_3 = df6_2.sort_index()

df6_3
# Out:
#             Alternative_für_Deutschland
# 2024-11-01                         1223
# 2024-11-02                         1323
# 2024-11-03                         1309
# 2024-11-04                         1601
# 2024-11-05                         1769
# ...                                 ...
# 2025-02-24                        46538
# 2025-02-25                        19592
# 2025-02-26                        14399
# 2025-02-27                         8108
# 2025-02-28                         6006
#
# [120 rows x 1 columns]

# %%
df6_3.axes
# Out:
# [DatetimeIndex(['2024-11-01', '2024-11-02', '2024-11-03', '2024-11-04',
#                 '2024-11-05', '2024-11-06', '2024-11-07', '2024-11-08',
#                 '2024-11-09', '2024-11-10',
#                 ...
#                 '2025-02-19', '2025-02-20', '2025-02-21', '2025-02-22',
#                 '2025-02-23', '2025-02-24', '2025-02-25', '2025-02-26',
#                 '2025-02-27', '2025-02-28'],
#                dtype='datetime64[ns]', length=120, freq=None),
#  Index(['Alternative_für_Deutschland'], dtype='object')]

# %%
plot = df6_3.plot(title='Daily Page Views')

# %%
# Make sure index is datetime
df6_3.index = pd.to_datetime(df6_3.index)

# Resample to weekly (sum of daily views per week)
weekly_views = df6_3.resample('W').sum()

# %%
weekly_views
# Out:
#             Alternative_für_Deutschland
# 2024-11-03                         3855
# 2024-11-10                        19957
# 2024-11-17                        35084
# 2024-11-24                        16297
# 2024-12-01                        13573
# 2024-12-08                        14034
# 2024-12-15                        13221
# 2024-12-22                        26205
# 2024-12-29                        21954
# 2025-01-05                        19617
# 2025-01-12                        40973
# 2025-01-19                        39375
# 2025-01-26                        43743
# 2025-02-02                        72867
# 2025-02-09                        59995
# 2025-02-16                        67722
# 2025-02-23                       136534
# 2025-03-02                        94643

# %%
plotweekly = weekly_views.plot(title='weekly Page Views', kind = 'bar')

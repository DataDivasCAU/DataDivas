# %% [markdown]
# # sorting comment Data

# %%
import pandas as pd

# %% [markdown]
# ## importing csv files

# %%
df_After = pd.read_csv('SahraWagenknechtCommentsAfter.csv')
df_After
# Out:
#       Unnamed: 0      videoId                      author  \
# 0              0  qh8xUmT2NyI      @christianstricker4563
# 1              1  qh8xUmT2NyI                @Armazone-21
# 2              2  qh8xUmT2NyI                    @Lyt1991
# 3              3  qh8xUmT2NyI  @janoschekheldderberge3446
# 4              4  qh8xUmT2NyI            @danielrebmann47
# ...          ...          ...                         ...
# 1975        1975  iL44wTd8Rbk                 @JeanDõ-k2b
# 1976        1976  iL44wTd8Rbk                  @adham1881
# 1977        1977  iL44wTd8Rbk              @NothIng-ky7ue
# 1978        1978  iL44wTd8Rbk                 @yanosh3359
# 1979        1979  iL44wTd8Rbk                 @Jana-io3cj
#
#                publishedAt  likeCount  \
# 0     2024-07-04T14:46:34Z         56
# 1     2024-05-24T08:14:44Z       1429
# 2     2024-07-01T13:28:41Z         24
# 3     2024-07-09T18:13:34Z         57
# 4     2024-05-26T22:19:50Z         21
# ...

# %%
df_Before = pd.read_csv('SahraWagenknechtCommentsBefore.csv')
df_Before
# Out:
#       Unnamed: 0      videoId                author           publishedAt  \
# 0              0  WCwx94TOGPQ      @andreasmann1111  2022-02-03T19:47:21Z
# 1              1  WCwx94TOGPQ    @marcelbollier1863  2022-02-03T19:38:12Z
# 2              2  WCwx94TOGPQ  @annemachowinski3292  2022-02-03T19:47:41Z
# 3              3  WCwx94TOGPQ  @mariuszgruchlik4367  2023-09-28T18:20:14Z
# 4              4  WCwx94TOGPQ        @Wollenschrank  2022-02-03T19:43:24Z
# ...          ...          ...                   ...                   ...
# 1995        1995  RhKSSpCXvnQ           @TheAmb1987  2020-12-03T17:03:43Z
# 1996        1996  RhKSSpCXvnQ            @yassveena  2020-12-04T18:50:39Z
# 1997        1997  RhKSSpCXvnQ         @peeachim3835  2020-12-03T17:26:21Z
# 1998        1998  RhKSSpCXvnQ     @waltraudgrau3560  2020-12-03T17:29:18Z
# 1999        1999  RhKSSpCXvnQ         @BlindedNumen  2020-12-04T19:43:08Z
#
#       likeCount                                               text  \
# ...

# %% [markdown]
# ## sorting comments by likes, cutting of at the top 500 and saving the Dataframe as a csv

# %%
df_Before_Popular = df_Before.sort_values(
    by='likeCount', ascending= False).head(500).reset_index(drop= True)
df_Before_Popular.to_csv('Popular_Comments_Before.csv')
df_Before_Popular
# Out:
#      Unnamed: 0      videoId            author           publishedAt  \
# 0            44  bQNsHivR9AU  @jochenkrebs9685  2022-10-20T19:19:36Z
# 1           121  kyUaDbVjMr0       @seemax7956  2021-11-19T07:22:26Z
# 2            40  bQNsHivR9AU    @sternmeer5346  2022-10-20T19:04:43Z
# 3             0  WCwx94TOGPQ  @andreasmann1111  2022-02-03T19:47:21Z
# 4           332  LbnRTQTJ7bQ         @fffrankk  2022-01-27T19:56:17Z
# ..          ...          ...               ...                   ...
# 495         160  aIylqpDNVIc  @letters_of_bach  2023-03-15T17:34:30Z
# 496         227  ulaw8J_YFLw   @lucasstolz3717  2023-06-16T16:10:16Z
# 497        1022  UDGl7rCLrVI         @Flo-1887  2021-02-18T16:09:02Z
# 498        1236  x4ms74GOJq8     @martinafueck  2023-09-07T16:50:40Z
# 499        1349  lY4e3H0NDV4     @uweboker5983  2023-06-22T20:40:15Z
#
#      likeCount                                               text  \
# 0         7917  Schade dass Politiker nicht persönlich für das...
# ...

# %%
df_After_Popular = df_After.sort_values(
    by='likeCount', ascending= False).head(500).reset_index(drop= True)
df_After_Popular.to_csv('Popular_Comments_After.csv')
df_After_Popular
# Out:
#      Unnamed: 0      videoId                 author           publishedAt  \
# 0           181  VVXrNSpEwJQ            @hubsda7883  2024-03-14T15:26:24Z
# 1           182  VVXrNSpEwJQ                @dm5559  2024-03-14T12:34:26Z
# 2           180  VVXrNSpEwJQ         @uweschmidt922  2024-03-14T12:38:15Z
# 3           141  SAGFQye1hT0           @harrybo1966  2024-05-27T16:45:19Z
# 4           200  -lXMP0RUy5A    @komscherbleier1316  2024-08-28T14:22:20Z
# ..          ...          ...                    ...                   ...
# 495          56  Qn-e6dIGpBY              @a.m.6277  2024-12-27T12:18:28Z
# 496        1521  Drg_jogctUQ                 @CCL01  2025-05-20T17:34:39Z
# 497         192  VVXrNSpEwJQ         @majdabboud879  2024-03-14T12:16:36Z
# 498        1523  Drg_jogctUQ          @deadbyflatus  2025-05-20T17:18:03Z
# 499         948  YcysDmbOWyw  @inzidenziaschulz7972  2024-09-26T18:13:12Z
#
#      likeCount                                               text  \
# ...

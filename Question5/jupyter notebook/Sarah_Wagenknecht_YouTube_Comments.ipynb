# %% [markdown]
# # Extracting comments from the 100 most popular youtube videos (Before and After the founding of the BSW)

# %% [markdown]
# ## imports

# %%
from googleapiclient.discovery import build
import pandas as pd
from datetime import datetime, timezone

# %%
from googleapiclient.errors import HttpError

# %% [markdown]
# ## API request

# %% [markdown]
# 'hidden' needs to be replaced by individual api key
#
# BEFORE_CSV and AFTER_CSV are the path to the stored csv files

# %%
API_KEY = "hidden"  
FOUNDING_DATE = datetime(2024, 1, 8, tzinfo=timezone.utc)
BEFORE_CSV = "csv/MostPopularVideosB.csv"  
AFTER_CSV = "csv/MostPopularVideosA.csv"

# %%
youtube = build("youtube", "v3", developerKey=API_KEY)


# -----------------------------
# FUNCTION TO GET COMMENTS FOR A VIDEO
# -----------------------------
def get_top_comments(video_id, max_comments=20):
    """
    Fetch top-level comments for a given video.
    max_comments: max number of comments to fetch per video
    """
    comments = []
    next_page_token = None

    while True:
        try:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                maxResults=100,
                pageToken=next_page_token,
                order="relevance",
                textFormat="plainText"
            )
            response = request.execute()
        except HttpError as e:
            error_reason = ""
            try:
                error_reason = e.error_details[0]['reason']
            except:
                pass
            if "commentsDisabled" in str(e):
                print(f"[SKIPPED] Comments disabled for video {video_id}")
            else:
                print(f"[ERROR] Could not fetch comments for video {video_id}: {e}")
            break  # Skip this video

        for item in response.get("items", []):
            top_comment = item["snippet"]["topLevelComment"]["snippet"]
            comments.append({
                "videoId": video_id,
                "author": top_comment.get("authorDisplayName"),
                "publishedAt": top_comment.get("publishedAt"),
                "likeCount": top_comment.get("likeCount", 0),
                "text": top_comment.get("textDisplay")
            })

            if len(comments) >= max_comments:
                break

        next_page_token = response.get("nextPageToken")
        if not next_page_token or len(comments) >= max_comments:
            break

    return comments

# %%
def extract_comments(df_videos, period_name):
    all_comments = []

    for _, row in df_videos.iterrows():
        video_id = row["videoId"]
        video_comments = get_top_comments(video_id)
        for c in video_comments:
            c["period"] = period_name
        all_comments.extend(video_comments)
  
    df_comments = pd.DataFrame(all_comments)
    if not df_comments.empty:
        df_comments['publishedAt'] = pd.to_datetime(df_comments['publishedAt'], utc=True)
    return df_comments

# %% [markdown]
# ## reading csv files and making sure pubishedt is in the datetime format needed

# %%
df_before = pd.read_csv(BEFORE_CSV)
df_before['publishedAt'] = pd.to_datetime(df_before['publishedAt'], utc=True)

# %%
df_after = pd.read_csv(AFTER_CSV)
df_after['publishedAt'] = pd.to_datetime(df_after['publishedAt'], utc=True)

# %% [markdown]
# ## using the extract comment function to extract the top 20 comments from all videos

# %%
df_comments_before = extract_comments(df_before, "Before Founding")

# %%
df_comments_after = extract_comments(df_after, "After Founding")

# %% [markdown]
# ## saving comment data in csv File

# %%
df_comments_before.to_csv('csv/SahraWagenknechtCommentsBefore.csv')
df_comments_before
# Out:
#           videoId                author           publishedAt  likeCount  \
# 0     WCwx94TOGPQ      @andreasmann1111  2022-02-03T19:47:21Z       5571
# 1     WCwx94TOGPQ    @marcelbollier1863  2022-02-03T19:38:12Z       1765
# 2     WCwx94TOGPQ  @annemachowinski3292  2022-02-03T19:47:41Z       1594
# 3     WCwx94TOGPQ  @mariuszgruchlik4367  2023-09-28T18:20:14Z         46
# 4     WCwx94TOGPQ        @Wollenschrank  2022-02-03T19:43:24Z        723
# ...           ...                   ...                   ...        ...
# 1995  RhKSSpCXvnQ           @TheAmb1987  2020-12-03T17:03:43Z        138
# 1996  RhKSSpCXvnQ            @yassveena  2020-12-04T18:50:39Z         29
# 1997  RhKSSpCXvnQ         @peeachim3835  2020-12-03T17:26:21Z         70
# 1998  RhKSSpCXvnQ     @waltraudgrau3560  2020-12-03T17:29:18Z         88
# 1999  RhKSSpCXvnQ         @BlindedNumen  2020-12-04T19:43:08Z         18
#
#                                                    text           period
# 0     Liebe Sahra schön dich gesund zu sehen. Im Geg...  Before Founding
# 1     Es tut gut und ist äusserst wichtig sich anzuh...  Before Founding
# 2     Toller Beitrag. Sehr aufschlussreich. Danke, F...  Before Founding
# 3     Wir sind alle doch Menschen. Wir sollten uns n...  Before Founding
# 4     Vielen Dank für die sachlichen Darstellungen, ...  Before Founding
# ...                                                 ...              ...
# 1995  so toll reden kann nur jemand, der nicht von i...  Before Founding
# 1996  Bravo!!! \nDa sieht man wieviel rüberkommt wen...  Before Founding
# 1997  Liebe Sarah, Dankeschön für wieder mal ein aus...  Before Founding
# 1998  Sehr gut Frau Wagenknecht , aber warum jetzt e...  Before Founding
# 1999  Ich liebe dich so sehr, Sahra!\n\nDu sprichst ...  Before Founding
#
# [2000 rows x 6 columns]

# %%
df_comments_after.to_csv('csv/SahraWagenknechtCommentsAfter.csv')
df_comments_after
# Out:
#           videoId                      author           publishedAt  \
# 0     qh8xUmT2NyI      @christianstricker4563  2024-07-04T14:46:34Z
# 1     qh8xUmT2NyI                @Armazone-21  2024-05-24T08:14:44Z
# 2     qh8xUmT2NyI                    @Lyt1991  2024-07-01T13:28:41Z
# 3     qh8xUmT2NyI  @janoschekheldderberge3446  2024-07-09T18:13:34Z
# 4     qh8xUmT2NyI            @danielrebmann47  2024-05-26T22:19:50Z
# ...           ...                         ...                   ...
# 1975  iL44wTd8Rbk                 @JeanDõ-k2b  2025-05-16T09:29:39Z
# 1976  iL44wTd8Rbk                  @adham1881  2025-05-16T06:56:55Z
# 1977  iL44wTd8Rbk              @NothIng-ky7ue  2025-05-16T07:49:01Z
# 1978  iL44wTd8Rbk                 @yanosh3359  2025-05-16T07:55:17Z
# 1979  iL44wTd8Rbk                 @Jana-io3cj  2025-05-16T15:08:06Z
#
#       likeCount                                               text  \
# 0            56  Ja genau wir wollen Frieden und keine Krigsunt...
# 1          1429  Münte war ja auch der Meinung, es sei ,,unfair...
# 2            24            Machen Sie weiter so frau wagenknecht 👍
# 3            57            ❤lichen Dank Frau Wagenknecht! 👍🕊️❤️🕊️👍
# 4            21  Sahra !! Seit Jahren ehrlich,  scharfsinnig. M...
# ...         ...                                                ...
# 1975         28  Das freut mich dass Politik so ein auf Deckel ...
# 1976        107  Ja, machen Sie das publik bitte, liebe Frau Wa...
# 1977        103                   Diese frau kriegt keiner unter ❤
# 1978         17                         Sehr sehr gut zu erfahren!
# 1979          8  Ich hab sie trotzdem gewählt, so Erhebungen sc...
#
#               period
# 0     After Founding
# 1     After Founding
# 2     After Founding
# 3     After Founding
# 4     After Founding
# ...              ...
# 1975  After Founding
# 1976  After Founding
# 1977  After Founding
# 1978  After Founding
# 1979  After Founding
#
# [1980 rows x 6 columns]

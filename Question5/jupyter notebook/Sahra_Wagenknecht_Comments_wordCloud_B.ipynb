# %% [markdown]
# # Step 5:
#
# # Creatin WordClouds for the Time Period before he founding of the BSW

# %% [markdown]
# ## Installs

# %%
# !pip install keybert
# Out:
# Requirement already satisfied: keybert in c:\users\asus\scoop\persist\python310\lib\site-packages (0.9.0)
# Requirement already satisfied: sentence-transformers>=0.3.8 in c:\users\asus\scoop\persist\python310\lib\site-packages (from keybert) (5.1.0)
# Requirement already satisfied: scikit-learn>=0.22.2 in c:\users\asus\scoop\persist\python310\lib\site-packages (from keybert) (1.7.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\asus\appdata\roaming\python\python310\site-packages (from keybert) (1.24.3)
# Requirement already satisfied: rich>=10.4.0 in c:\users\asus\scoop\persist\python310\lib\site-packages (from keybert) (14.1.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\asus\scoop\persist\python310\lib\site-packages (from rich>=10.4.0->keybert) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\asus\scoop\persist\python310\lib\site-packages (from rich>=10.4.0->keybert) (2.19.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\asus\scoop\persist\python310\lib\site-packages (from scikit-learn>=0.22.2->keybert) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\asus\scoop\persist\python310\lib\site-packages (from scikit-learn>=0.22.2->keybert) (3.6.0)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\asus\scoop\persist\python310\lib\site-packages (from scikit-learn>=0.22.2->keybert) (1.15.3)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\asus\scoop\persist\python310\lib\site-packages (from sentence-transformers>=0.3.8->keybert) (4.15.0)
# Requirement already satisfied: tqdm in c:\users\asus\scoop\persist\python310\lib\site-packages (from sentence-transformers>=0.3.8->keybert) (4.67.1)
# Requirement already satisfied: Pillow in c:\users\asus\scoop\persist\python310\lib\site-packages (from sentence-transformers>=0.3.8->keybert) (11.3.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\asus\scoop\persist\python310\lib\site-packages (from sentence-transformers>=0.3.8->keybert) (4.56.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\asus\scoop\persist\python310\lib\site-packages (from sentence-transformers>=0.3.8->keybert) (2.8.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\asus\scoop\persist\python310\lib\site-packages (from sentence-transformers>=0.3.8->keybert) (0.34.4)
# Requirement already satisfied: packaging>=20.9 in c:\users\asus\scoop\persist\python310\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.3.8->keybert) (25.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\asus\scoop\persist\python310\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.3.8->keybert) (2025.7.0)
# Requirement already satisfied: filelock in c:\users\asus\scoop\persist\python310\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.3.8->keybert) (3.19.1)
# Requirement already satisfied: requests in c:\users\asus\scoop\persist\python310\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.3.8->keybert) (2.32.5)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\asus\scoop\persist\python310\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.3.8->keybert) (6.0.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\asus\scoop\persist\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.4.0->keybert) (0.1.2)
# Requirement already satisfied: jinja2 in c:\users\asus\scoop\persist\python310\lib\site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (3.1.6)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\asus\scoop\persist\python310\lib\site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (1.14.0)
# Requirement already satisfied: networkx in c:\users\asus\scoop\persist\python310\lib\site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (3.4.2)
# Requirement already satisfied: colorama in c:\users\asus\scoop\persist\python310\lib\site-packages (from tqdm->sentence-transformers>=0.3.8->keybert) (0.4.6)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\asus\scoop\persist\python310\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert) (0.6.2)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\asus\scoop\persist\python310\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert) (0.22.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\asus\scoop\persist\python310\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert) (2025.8.29)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\asus\scoop\persist\python310\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\scoop\persist\python310\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (3.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\scoop\persist\python310\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.3.8->keybert) (2025.8.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\asus\scoop\persist\python310\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.3.8->keybert) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\scoop\persist\python310\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.3.8->keybert) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\scoop\persist\python310\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.3.8->keybert) (2.5.0)

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\asus\scoop\persist\python310\lib\site-packages (1.9.4)
# Requirement already satisfied: matplotlib in c:\users\asus\scoop\persist\python310\lib\site-packages (from wordcloud) (3.10.6)
# Requirement already satisfied: pillow in c:\users\asus\scoop\persist\python310\lib\site-packages (from wordcloud) (11.3.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\asus\appdata\roaming\python\python310\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\scoop\persist\python310\lib\site-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\asus\scoop\persist\python310\lib\site-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\scoop\persist\python310\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asus\scoop\persist\python310\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\scoop\persist\python310\lib\site-packages (from matplotlib->wordcloud) (4.59.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\asus\scoop\persist\python310\lib\site-packages (from matplotlib->wordcloud) (3.2.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\scoop\persist\python310\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: six>=1.5 in c:\users\asus\scoop\persist\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in c:\users\asus\scoop\persist\python310\lib\site-packages (4.67.1)
# Requirement already satisfied: colorama in c:\users\asus\scoop\persist\python310\lib\site-packages (from tqdm) (0.4.6)

# %%
import pandas as pd
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import keybert

# %% [markdown]
# importing CSV Files

# %%
import os



before_path = os.path.abspath('csv/Popular_Comments_Before.csv')
after_path  = os.path.abspath('csv/Popular_Comments_After.csv')


# CSV-Dateien laden, wenn sie existieren
if os.path.exists(before_path) and os.path.exists(after_path):
    Comments_Before = pd.read_csv(before_path)
    Comments_After  = pd.read_csv(after_path)
    print("Dateien erfolgreich geladen!")
else:
    print("Eine oder beide Dateien wurden nicht gefunden. Pfade prüfen!")
# Out:
# Dateien erfolgreich geladen!

# %% [markdown]
# ## Using Keybert to extract Keywords from Comments

# %%
model = keybert.KeyBERT()

# %%
keywords_list = []
for row_i in tqdm(range(Comments_Before.shape[0])):
    row = Comments_Before.iloc[row_i]
    keywords = []
    title_abstract = row['text'] 
    keywords.append(model.extract_keywords(title_abstract,
                       keyphrase_ngram_range = (1,1)))
    keywords.append(model.extract_keywords(title_abstract,
                       keyphrase_ngram_range = (1,2)))
    keywords_list.append(keywords)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
Comments_Before['keywords'] = keywords_list

# %%
Comments_Before
# Out:
#      Unnamed: 0.1  Unnamed: 0      videoId            author  \
# 0               0          44  bQNsHivR9AU  @jochenkrebs9685
# 1               1         121  kyUaDbVjMr0       @seemax7956
# 2               2          40  bQNsHivR9AU    @sternmeer5346
# 3               3           0  WCwx94TOGPQ  @andreasmann1111
# 4               4         332  LbnRTQTJ7bQ         @fffrankk
# ..            ...         ...          ...               ...
# 495           495         160  aIylqpDNVIc  @letters_of_bach
# 496           496         227  ulaw8J_YFLw   @lucasstolz3717
# 497           497        1022  UDGl7rCLrVI         @Flo-1887
# 498           498        1236  x4ms74GOJq8     @martinafueck
# 499           499        1349  lY4e3H0NDV4     @uweboker5983
#
#               publishedAt  likeCount  \
# 0    2022-10-20T19:19:36Z       7917
# 1    2021-11-19T07:22:26Z       7385
# 2    2022-10-20T19:04:43Z       5816
# 3    2022-02-03T19:47:21Z       5571
# 4    2022-01-27T19:56:17Z       5275
# ..                    ...        ...
# 495  2023-03-15T17:34:30Z        501
# 496  2023-06-16T16:10:16Z        500
# 497  2021-02-18T16:09:02Z        500
# 498  2023-09-07T16:50:40Z        499
# 499  2023-06-22T20:40:15Z        498
#
#                                                   text           period  \
# 0    Schade dass Politiker nicht persönlich für das...  Before Founding
# 1    Um Loriot zu zitieren „In Krisenzeiten suchen ...  Before Founding
# 2    Absolut jedes Wort, das Sie zur Beschreibung d...  Before Founding
# 3    Liebe Sahra schön dich gesund zu sehen. Im Geg...  Before Founding
# 4    Wie üblich: Tausend Dank dafür, eine der wenig...  Before Founding
# ..                                                 ...              ...
# 495                           Bitte endlich Frieden!!!  Before Founding
# 496  Freiheit für Julian assange. Wikileaks muss ar...  Before Founding
# 497   Wie recht Sie mal wieder haben Frau Wagenknecht!  Before Founding
# 498  Die Ampel muss unbedingt abtreten, sonst fährt...  Before Founding
# 499  Danke Frau Dr. Wagenknecht! Sie haben das Wiss...  Before Founding
#
#                                               keywords
# 0    [[(müssen, 0.5075), (anrichten, 0.4708), (haft...
# 1    [[(krisenzeiten, 0.4251), (haltung, 0.4008), (...
# 2    [[(beschreibung, 0.5429), (beschreiben, 0.4969...
# 3    [[(gesund, 0.467), (sehen, 0.3641), (gegensatz...
# 4    [[(tausend, 0.5395), (dafür, 0.4174), (äußern,...
# ..                                                 ...
# 495  [[(endlich, 0.6916), (frieden, 0.5075), (bitte...
# 496  [[(assange, 0.5503), (wikileaks, 0.5146), (fre...
# 497  [[(wagenknecht, 0.6434), (recht, 0.496), (wied...
# 498  [[(abtreten, 0.4313), (komplette, 0.3988), (fä...
# 499  [[(rechtschaffenheit, 0.5522), (wagenknecht, 0...
#
# [500 rows x 9 columns]

# %% [markdown]
# flatten nested keyword list

# %%
def flatten(xss):
    return [x for xs in xss for x in xs]

# %%
flattened_keywords = flatten(flatten(keywords_list))

# %%
flattened_keywords = [item[0] for item in flattened_keywords]

# %%
flattened_keywords
# Out:
# ['müssen',
#  'anrichten',
#  'haften',
#  'persönlich',
#  'nicht',
#  'haften müssen',
#  'das haften',
#  'müssen sie',
#  'sie anrichten',
#  'nicht persönlich',
#  'krisenzeiten',
#  'haltung',
#  'intelligente',
#  'beiträge',
#  'schuldigen',
#  'intelligente nach',
#  'zitieren krisenzeiten',
#  'beiträge und',
#  'nach schuldigen',
#  'idioten nach',
#  'beschreibung',
#  'beschreiben',
#  'bezeichnen',
#  'großes',
#  'herzlichen',
#  'zur beschreibung',
#  'beschreibung der',
#  'zu beschreiben',
#  'beschreibung',
#  'beschreiben',
#  'gesund',
#  'sehen',
#  'gegensatz',
#  'einen',
#  'bleiben',
#  'dich gesund',
#  'gesund zu',
#  'gesund',
#  'uns erhalten',
#  'gegensatz zu',
#  'tausend',
#  'dafür',
#  'äußern',
#  'politik',
#  'und',
#  'tausend dank',
#  'üblich tausend',
#  'tausend',
#  'dafür eine',
#  'deutschen politik',
#  'abgeht',
#  'einfach',
#  'wagenknecht',
#  'wahnsinn',
#  'klaren',
#  'nur wahnsinn',
#  'einfach nur',
#  'hier abgeht',
#  'abgeht danke',
#  'wahnsinn hier',
#  'tolerieren',
#  'totgeschwiegen',
#  'einstellung',
#  'land',
#  'politische',
#  'politische einstellung',
#  'tolerieren dass',
#  'einfach totgeschwiegen',
#  'ein angriff',
#  'welche politische',
#  'herzlichen',
#  'hervorragende',
#  'bundestag',
#  'hochachtung',
#  'größte',
#  'hervorragende rede',
#  'herzlichen dank',
#  'herzlichen',
#  'ihre hervorragende',
#  'hervorragende',
#  'wagenknecht',
#  'ihrer',
#  'und',
#  'unterstützen',
#  'sie',
#  'wagenknecht bitte',
#  'frau wagenknecht',
#  'wagenknecht',
#  'weiterhin unterstützen',
#  'sie weiterhin',
#  'lichtblick',
#  'unermüdliche',
#  'politik',
#  'arbeit',
#  'der',
#  'ein lichtblick',
#  'lichtblick der',
#  'unermüdliche arbeit',
#  'aktuellen politik',
#  'arbeit ein',
#  'parteilose',
#  'lassen',
#  'bürgerbegehren',
#  'unterschriften',
#  'wagenknecht',
#  'parteilose kanzlerin',
#  'wagenknecht lassen',
#  'ein bürgerbegehren',
#  'einschüchtern starten',
#  'lassen sie',
#  'wagenknecht',
#  'bitte',
#  'sie',
#  'danke',
#  'weiter',
#  'frau wagenknecht',
#  'bitte machen',
#  'sie weiter',
#  'wagenknecht retten',
#  'machen sie',
#  'waffenlieferungen',
#  'politiker',
#  'befürworten',
#  'sollten',
#  'auch',
#  'waffenlieferungen befürworten',
#  'die politiker',
#  'die waffenlieferungen',
#  'waffenlieferungen',
#  'politiker die',
#  'lächerlichkeit',
#  'deutschland',
#  'nicht',
#  'überbieten',
#  'ist',
#  'ist lächerlichkeit',
#  'lächerlichkeit nicht',
#  'lächerlichkeit',
#  'deutschland ist',
#  'deutschland',
#  'außenministerin',
#  'diplomatisch',
#  'ich',
#  'wünschte',
#  'feingefühl',
#  'außenministerin sie',
#  'wären außenministerin',
#  'außenministerin',
#  'sind diplomatisch',
#  'diplomatisch',
#  'einschränkungen',
#  'keine',
#  'vorher',
#  'und',
#  'ist',
#  'weg vorher',
#  'vorher ist',
#  'wir keine',
#  'freiheit vorher',
#  'vorher dürfen',
#  'auszusprechen',
#  'angegriffen',
#  'ständig',
#  'wieder',
#  'dafür',
#  'wahrheit auszusprechen',
#  'heftig angegriffen',
#  'dafür ständig',
#  'angegriffen wird',
#  'sie dafür',
#  'realismus',
#  'hartnäckigkeit',
#  'unerschütterlichen',
#  'unkorrumpierbaren',
#  'ihren',
#  'zum realismus',
#  'hartnäckigkeit ihren',
#  'ihre hartnäckigkeit',
#  'realismus',
#  'ihren unkorrumpierbaren',
#  'lichtblicke',
#  'wagenknecht',
#  'eine',
#  'düstere',
#  'kämpfen',
#  'wenigen lichtblicke',
#  'lichtblicke diese',
#  'frau wagenknecht',
#  'wagenknecht sie',
#  'lichtblicke',
#  'endlich',
#  'ich',
#  'keine',
#  'partei',
#  'eigene',
#  'sie endlich',
#  'endlich eigene',
#  'partei ich',
#  'keine nerven',
#  'eigene partei',
#  'leicht',
#  'gesundem',
#  'wagenknecht',
#  'sterne',
#  'menschenverstand',
#  'mit gesundem',
#  'gesundem menschenverstand',
#  'wagenknecht sie',
#  'frau wagenknecht',
#  'sie sterne',
#  'einfach',
#  'endlich',
#  'wagenknecht',
#  'ich',
#  'beste',
#  'partei ich',
#  'sie endlich',
#  'sind einfach',
#  'wagenknecht gründen',
#  'einfach die',
#  'straße',
#  'wagenknecht',
#  'deutschland',
#  'auf',
#  'ich',
#  'straße flyer',
#  'der straße',
#  'straße',
#  'schönes deutschland',
#  'deutschland ich',
#  'einzige',
#  'bleiben',
#  'politikerin',
#  'erhalten',
#  'verstand',
#  'einzige politikerin',
#  'verstand bleiben',
#  'mit verstand',
#  'uns erhalten',
#  'die einzige',
#  'allerallerschlimmste',
#  'kanzlerkandidaten',
#  'durch',
#  'tatsache',
#  'knalltüten',
#  'das allerallerschlimmste',
#  'allerallerschlimmste unserem',
#  'allerallerschlimmste',
#  'durch inkompetenten',
#  'als kanzlerkandidaten',
#  'nüchterne',
#  'miteinander',
#  'eine',
#  'friedliches',
#  'ich',
#  'eine russin',
#  'russin und',
#  'friedliches miteinander',
#  'nüchterne und',
#  'miteinander auf',
#  'äußern',
#  'eine',
#  'deutliche',
#  'schande',
#  'machen',
#  'eine schande',
#  'schande machen',
#  'machen sie',
#  'die ampel',
#  'sauber sie',
#  'russe',
#  'diejenigen',
#  'und',
#  'ausgesetzt',
#  'anfeindungen',
#  'als russe',
#  'russe',
#  'russe hier',
#  'diejenigen dafür',
#  'diejenigen',
#  'auszusprechen',
#  'rede',
#  'haben',
#  'sehr',
#  'eine',
#  'rede vielen',
#  'sehr starke',
#  'wahrheit auszusprechen',
#  'starke rede',
#  'eine sehr',
#  'wagenknecht',
#  'frauen',
#  'frauenquote',
#  'demokratie',
#  'politikerin',
#  'frau wagenknecht',
#  'frau politikerin',
#  'wagenknecht ist',
#  'eine frau',
#  'wagenknecht',
#  'nächsten',
#  'und',
#  'tage',
#  'meinen',
#  'ein',
#  'nächsten tage',
#  'tage und',
#  'die nächsten',
#  'und viel',
#  'und ein',
#  'wirtschaft',
#  'einen',
#  'eine',
#  'kanzlerin',
#  'nachdenklich',
#  'die wirtschaft',
#  'wirtschaft auf',
#  'kanzlerin abfährt',
#  'nachdenklich machen',
#  'wirtschaft',
#  'haben',
#  'vermisst',
#  'chaotischen',
#  'sehr',
#  'vernunft',
#  'sehr vermisst',
#  'chaotischen zeiten',
#  'vermisst diesen',
#  'haben sie',
#  'wir haben',
#  'pflegekräften',
#  'schande',
#  'umgegangen',
#  'eine',
#  'unseren',
#  'pflegekräften umgegangen',
#  'eine schande',
#  'unseren pflegekräften',
#  'pflegekräften',
#  'schande wie',
#  'einsatz',
#  'nicht',
#  'ausspricht',
#  'einzige',
#  'danke',
#  'einsatz bitte',
#  'ihren einsatz',
#  'einsatz',
#  'ausspricht ich',
#  'das ausspricht',
#  'schaffen',
#  'hutschnur',
#  'bleiben',
#  'zu',
#  'schon',
#  'zuhören schon',
#  'die hutschnur',
#  'es schaffen',
#  'schaffen ruhig',
#  'zu bleiben',
#  'himmel',
#  'wagenknechts',
#  'bestehen',
#  'politiker',
#  'zu',
#  'himmel auf',
#  'wagenknechts bestehen',
#  'den himmel',
#  'zu 50',
#  'viel herz',
#  'freude',
#  'wahrheitsgetreu',
#  'freundlich',
#  'wagenknecht',
#  'vorzutragen',
#  'freude ist',
#  'größte freude',
#  'freude',
#  'wahrheitsgetreu faktisch',
#  'frau wagenknecht',
#  'wagenknecht',
#  'lichtblick',
#  'politikzirkus',
#  'ist',
#  'einzige',
#  'wagenknecht sie',
#  'lichtblick diesem',
#  'frau wagenknecht',
#  'einzige lichtblick',
#  'politikzirkus sie',
#  'niemand',
#  'ich',
#  'meine',
#  'keinem',
#  'kindheit',
#  'meine kindheit',
#  'keinem kind',
#  'das niemand',
#  'müssen ich',
#  'kind das',
#  'eier',
#  'einzige',
#  'danke',
#  'sie',
#  'ehrlich',
#  'die eier',
#  'eier',
#  'äußern danke',
#  'eier hat',
#  'die einzige',
#  'privilegien',
#  'frechheit',
#  'eine',
#  'das',
#  'ist',
#  'privilegien ist',
#  'wort privilegien',
#  'privilegien',
#  'eine frechheit',
#  'ist eine',
#  'berichterstattung',
#  'reflektiert',
#  'bereicherung',
#  'wirklich',
#  'eine',
#  'berichterstattung ist',
#  'ihre berichterstattung',
#  'berichterstattung',
#  'reflektiert sie',
#  'reflektiert',
#  'gürtellinie',
#  'analytisch',
#  'hammer',
#  'und',
#  'sachlich',
#  'die gürtellinie',
#  'der hammer',
#  'sachlich analytisch',
#  'analytisch und',
#  'hammer sachlich',
#  'politikerin',
#  'kanzlerin',
#  'menschenverstand',
#  'klarem',
#  'eine',
#  'einzige politikerin',
#  'klarem menschenverstand',
#  'politikerin mit',
#  'mit klarem',
#  'super kanzlerin',
#  'unermüdlichen',
#  'einsatz',
#  'eine',
#  'rational',
#  'menschen',
#  'unermüdlichen einsatz',
#  'denkende menschen',
#  'ihren unermüdlichen',
#  'wichtiger ist',
#  'umso wichtiger',
#  'bundesregierung',
#  'landesverrat',
#  'und',
#  'verklagt',
#  'hoch',
#  'bundesregierung wegen',
#  'die bundesregierung',
#  'und landesverrat',
#  'bundesregierung',
#  'hoch und',
#  'vorwürfe',
#  'schmidt',
#  'später',
#  'grünen',
#  'machen',
#  'bitterste vorwürfe',
#  'vorwürfe machen',
#  'später einmal',
#  'vorwürfe',
#  'sich später',
#  'bundestagsabstimmung',
#  'bundesregierung',
#  'bundestag',
#  'corona',
#  'deutlich',
#  'der bundesregierung',
#  'der bundestagsabstimmung',
#  'bundesregierung vorgesehenen',
#  'der bundestag',
#  'bundestag und',
#  'endlich',
#  'nicht',
#  'wagenknecht',
#  'einige',
#  'vernunft',
#  'zur vernunft',
#  'sie endlich',
#  'wagenknecht sie',
#  'endlich zur',
#  'frau wagenknecht',
#  'wagenknecht',
#  'lichtblick',
#  'weiter',
#  'menschen',
#  'eines',
#  'ein lichtblick',
#  'lichtblick ende',
#  'wagenknecht machen',
#  'frau wagenknecht',
#  'weiter menschen',
#  'rechtliche',
#  'öffentlich',
#  'nicht',
#  'beiträge',
#  'ich',
#  'rechtliche tv',
#  'beiträge wie',
#  'diese gehören',
#  'öffentlich rechtliche',
#  'rechtliche',
#  'darstellung',
#  'guten',
#  'gute',
#  'bleiben',
#  'wagenknecht',
#  'gute darstellung',
#  'sehr gute',
#  'der momentanen',
#  'darstellung der',
#  'guten abend',
#  'russland',
#  'frieden',
#  'machen',
#  'friedensgarantie',
#  'guten',
#  'und russland',
#  'zu russland',
#  'russland macht',
#  'russland hatten',
#  'russland',
#  'wagenknecht',
#  'fakten',
#  'und',
#  'der',
#  'endlich',
#  'mit fakten',
#  'politik der',
#  'und mit',
#  'der politik',
#  'frau wagenknecht',
#  'belächelt',
#  'ständig',
#  'nicht',
#  'nämlich',
#  'und',
#  'und belächelt',
#  'belächelt sie',
#  'nämlich recht',
#  'sie schaffen',
#  'ihr ständig',
#  'wagenknecht',
#  'lichtblick',
#  'gebracht',
#  'scharfsinnig',
#  'linken',
#  'lichtblick der',
#  'ein lichtblick',
#  'frau wagenknecht',
#  'punkt gebracht',
#  'der linken',
#  'auch',
#  'politiker',
#  'aufhalten',
#  'nicht',
#  'vernünftige',
#  'vernünftige politiker',
#  'auch vernünftige',
#  'der minderheit',
#  'hören auch',
#  'weiter und',
#  'meine',
#  'danke',
#  'menschen',
#  'viele',
#  'superheldin',
#  'meine superheldin',
#  'superheldin danke',
#  'viele menschen',
#  'danke für',
#  'meine',
#  'einsetzen',
#  'menschen',
#  'deutschland',
#  'dass',
#  'und',
#  'darin einsetzen',
#  'die menschen',
#  'menschen darin',
#  'danke dass',
#  'für deutschland',
#  'wagenknecht',
#  'kanzlerkandidatin',
#  'vergleicht',
#  'aussagen',
#  'und',
#  'frau wagenknecht',
#  'eine kanzlerkandidatin',
#  'wagenknecht wäre',
#  'wagenknecht',
#  'kanzlerkandidatin wenn',
#  'politischen',
#  'gesunde',
#  'zunehmend',
#  'verschwindet',
#  'menschenverstand',
#  'gesunde menschenverstand',
#  'der gesunde',
#  'politischen ämtern',
#  'menschenverstand politischen',
#  'zunehmend verschwindet',
#  'gerechte',
#  'weitermachen',
#  'eine',
#  'erheben',
#  'und',
#  'weitermachen und',
#  'soziale gerechte',
#  'gerechte zukunft',
#  'gerechte',
#  'sahra weitermachen',
#  'wagenknecht',
#  'deutschen',
#  'ich',
#  'eine',
#  'ihnen',
#  'wagenknecht ich',
#  'bürgern eine',
#  'deutschen bürgern',
#  'geben deutschen',
#  'eine stimme',
#  'fühle',
#  'äußern',
#  'wagenknecht',
#  'zu',
#  'und',
#  'und fühle',
#  'aus ich',
#  'wagenknecht ich',
#  'fühle liebe',
#  'das aus',
#  'sie',
#  'großes',
#  'viele',
#  'eine',
#  'und',
#  'sie eine',
#  'fühlen sie',
#  'sie und',
#  'und sie',
#  'viele fühlen',
#  'falschen',
#  'ich',
#  'fühle',
#  'film',
#  'und',
#  'ich fühle',
#  'falschen film',
#  'mindestens jahren',
#  'film und',
#  'falschen',
#  'nicht',
#  'regierung',
#  'einfach',
#  'hirn',
#  'gibt',
#  'leider nicht',
#  'hirn gibt',
#  'mit hirn',
#  'der regierung',
#  'nicht der',
#  'kandidieren',
#  'einen',
#  'kanzlerin',
#  'eindringlich',
#  'umgehen',
#  'eine kanzlerin',
#  'einen posten',
#  'kandidieren sie',
#  'und kandidieren',
#  'kanzlerin wie',
#  'wagenknecht',
#  'menschenverstand',
#  'politikerin',
#  'einzige',
#  'und',
#  'sahra wagenknecht',
#  'einzige politikerin',
#  'mit menschenverstand',
#  'menschenverstand chapeau',
#  'wagenknecht weit',
#  'vielen',
#  'wagenknecht',
#  'einsatz',
#  'deutschland',
#  'hofreitern',
#  'einsatz liebe',
#  'hofreitern und',
#  'menschen hoffnung',
#  'wagenknecht sie',
#  'vielen menschen',
#  'eine',
#  'der',
#  'ich',
#  'wenigen',
#  'politiker',
#  'wenigen politiker',
#  'ich vertraue',
#  'der wenigen',
#  'eine der',
#  'politiker denen',
#  'wagenknecht',
#  'deutschland',
#  'politiker',
#  'politik',
#  'ziehen',
#  'der politik',
#  'wagenknecht bitte',
#  'politik zurück',
#  'politiker wie',
#  'frau wagenknecht',
#  'wagenknecht',
#  'hose',
#  'eier',
#  'bundestag',
#  'auf',
#  'wagenknecht sie',
#  'frau wagenknecht',
#  'wagenknecht ich',
#  'der hose',
#  'wagenknecht',
#  'geradlinigkeit',
#  'ihr',
#  'ihnen',
#  'jahr',
#  'herzlichen',
#  'ihre geradlinigkeit',
#  'engagement und',
#  'ihr engagement',
#  'jahr und',
#  'geradlinigkeit',
#  'wagenknecht',
#  'endlich',
#  'das',
#  'hut',
#  'volk',
#  'endlich jemand',
#  'das volk',
#  'ab endlich',
#  'frau wagenknecht',
#  'wagenknecht',
#  'leichter',
#  'brandt',
#  'macht',
#  'menschen',
#  'teufel',
#  'leichter macht',
#  'nicht leichter',
#  'der ganzen',
#  'ganzen politik',
#  'willy brandt',
#  'gegen',
#  'unterbrecherei',
#  'souverän',
#  'anfang',
#  'aussprechen',
#  'und souverän',
#  'gegen anfang',
#  'anfang durften',
#  'unterbrecherei los',
#  'nur bewundern',
#  'zuzuhören',
#  'wagenknecht',
#  'intelligenten',
#  'worten',
#  'danke',
#  'intelligenten worten',
#  'ihren intelligenten',
#  'zuzuhören danke',
#  'worten zuzuhören',
#  'zuzuhören',
#  'liebe',
#  'und',
#  'grüße',
#  'eine',
#  'ausführungen',
#  'liebe grüße',
#  'intelligenten ausführungen',
#  'erhalten liebe',
#  'liebe frau',
#  'frau wagenknecht',
#  '60',
#  'ich',
#  '50',
#  '67',
#  'erklären',
#  '60 jahren',
#  '60',
#  '50 60',
#  '67 jahre',
#  'jahre arbeiten',
#  'unglaublich',
#  'politik',
#  'und',
#  'land',
#  'sie',
#  'unserer politik',
#  'unglaublich viel',
#  'es unglaublich',
#  'politik leider',
#  'sie sind',
#  'hintergrundwissen',
#  'wagenknecht',
#  'geschichtliches',
#  'merkt',
#  'und',
#  'hintergrundwissen und',
#  'geschichtliches hintergrundwissen',
#  'wagenknecht verdient',
#  'bildung besitzt',
#  'höchsten respekt',
#  'wohltat',
#  'wöchentlich',
#  'argumente',
#  'ausnahme',
#  'diese',
#  'eine wohltat',
#  'wohltat wöchentlich',
#  'wöchentlich diese',
#  'zu hören',
#  'die ausnahme',
#  'wagenknecht',
#  'hoffnungsschimmer',
#  'wirklich',
#  'vielen',
#  'horizont',
#  'hoffnungsschimmer horizont',
#  'ein hoffnungsschimmer',
#  'horizont vielen',
#  'wagenknecht sie',
#  'vielen dank',
#  'aussprechen',
#  'rentner',
#  'würde',
#  'dass',
#  'wahnsinn',
#  'aussprechen rentner',
#  'wahrheit aussprechen',
#  'aussprechen',
#  'danke dass',
#  'rentner bekommen',
#  'privilegien',
#  'grundrechte',
#  'verfassungsfeindlich',
#  'bezeichnen',
#  'zu',
#  'privilegien zu',
#  'als privilegien',
#  'privilegien',
#  'grundrechte als',
#  'grundrechte',
#  'klarer',
#  'geht',
#  'sahra',
#  'kann',
#  'danke',
#  'klarer und',
#  'geht danke',
#  'hier geht',
#  'danke sahra',
#  'besser kann',
#  'lichtblick',
#  'wagenknecht',
#  'und',
#  'sie',
#  'weiter',
#  'ein lichtblick',
#  'lichtblick machen',
#  'wagenknecht sie',
#  'frau wagenknecht',
#  'weiter und',
#  'politikerin',
#  'vertrauens',
#  'eine',
#  'des',
#  'eine politikerin',
#  'politikerin des',
#  'des vertrauens',
#  'politikerin',
#  'vertrauens',
#  'finde',
#  'gar',
#  'irrsinn',
#  'wir',
#  'passiert',
#  'finde gar',
#  'gar keine',
#  'diesen irrsinn',
#  'irrsinn wir',
#  'ich finde',
#  'unglaublich',
#  'und',
#  'dringend',
#  'unserem',
#  'aussprechen',
#  'unglaublich danke',
#  'ist unglaublich',
#  'unserem land',
#  'dringend und',
#  'dass unserem',
#  'gebracht',
#  'gesprochen',
#  'punkt',
#  'menschen',
#  'und',
#  'punkt gebracht',
#  'menschen gesprochen',
#  'gesprochen und',
#  'den punkt',
#  'gebracht',
#  'recht',
#  'politik',
#  'politiker',
#  'nicht',
#  'deutschen',
#  'politik nicht',
#  'deutschen politik',
#  'die politiker',
#  'politiker hier',
#  'wahnsinnig sahra',
#  'gerechtigkeit',
#  'frieden',
#  'freiheit',
#  'dringender',
#  'und',
#  'frieden freiheit',
#  'und dringender',
#  'freiheit und',
#  'und europa',
#  'gerechtigkeit deutschland',
#  'aufklärung',
#  'zu',
#  'das',
#  'wagenknecht',
#  'ich',
#  'aufklärung ich',
#  'die aufklärung',
#  'augen zu',
#  'zu öffnen',
#  'das sie',
#  'alle',
#  'uns',
#  'und',
#  'sehen',
#  'europa',
#  'uns alle',
#  'für uns',
#  'alle nicht',
#  'alle',
#  'uns',
#  'rande',
#  'geht',
#  'endlich',
#  'nicht',
#  'protest',
#  'politik rande',
#  'sachen protest',
#  'endlich geht',
#  'rande des',
#  'geht mal',
#  'sendungen',
#  'kritischen',
#  'kriegen',
#  'presse',
#  'sehen',
#  'wie kriegen',
#  'kriegen wir',
#  'deutsche presse',
#  'und tv',
#  'medien lesen',
#  'wagenknecht',
#  'kanzlerin',
#  'meine',
#  'danke',
#  'sind',
#  'meine kanzlerin',
#  'frau wagenknecht',
#  'sind meine',
#  'kanzlerin danke',
#  'wagenknecht',
#  'das',
#  ...]

# %% [markdown]
# creating DataFrame with keywords and their frequencies

# %%
keywords_df = pd.DataFrame()
keywords_df['words'] = Counter(flattened_keywords).keys()
keywords_df['numbers'] = Counter(flattened_keywords).values()
frequent_words = keywords_df.loc[keywords_df['numbers'] > 1].sort_values(
    by='numbers', ascending=False)
frequent_words
# Out:
#                   words  numbers
# 48          wagenknecht      200
# 77     frau wagenknecht       93
# 41                  und       90
# 123                 ich       57
# 156                eine       57
# ...                 ...      ...
# 856              spitze        2
# 848              grippe        2
# 839                 rot        2
# 835           kompetenz        2
# 2849  rechtschaffenheit        2
#
# [551 rows x 2 columns]

# %% [markdown]
# filtering keywords

# %%
# Define custom list of words to exclude (case insensitive)
filtered_words = [
    "ich", 
    "und", 
    "nicht", 
    "das", 
    "ist", 
    "zu", 
    "der", 
    "eine", 
    'wagenknecht sie', 
    "sie"
    ]

# Filter out words by lowercasing
filtered_keywords = [w for w in flattened_keywords 
                     if w.lower() not in [fw.lower() for fw in filtered_words]]

# %% [markdown]
# creating Dataframe with filtered Keywords

# %%
filtered_keywords_df = pd.DataFrame()
filtered_keywords_df['words'] = Counter(filtered_keywords).keys()
filtered_keywords_df['numbers'] = Counter(filtered_keywords).values()
frequent_words_filtered = filtered_keywords_df.loc[filtered_keywords_df['numbers'] > 1].sort_values(by='numbers', ascending=False)

# %% [markdown]
# saving filtered keywords in JSOn for the Website

# %%
import json 

json_str = frequent_words_filtered.to_json(orient="records", indent=2, force_ascii=False)

with open("csv/Sahra_Wagenknecht_Words_B.json", "w", encoding="utf-8") as f:
    f.write(json_str)

# %% [markdown]
# ## Visualisations

# %% [markdown]
# creating stacked bubble chart (these were not used)

# %%
import matplotlib.pyplot as plt
import numpy as np
import random


#source: https://matplotlib.org/stable/gallery/misc/packed_bubbles.html#sphx-glr-gallery-misc-packed-bubbles-py
class BubbleChart:
    def __init__(self, area, bubble_spacing=0):
        """
        Setup for bubble collapse.
        """
        area = np.asarray(area)
        r = np.sqrt(area / np.pi)

        self.bubble_spacing = bubble_spacing
        self.bubbles = np.ones((len(area), 4))
        self.bubbles[:, 2] = r
        self.bubbles[:, 3] = area
        self.maxstep = 2 * self.bubbles[:, 2].max() + self.bubble_spacing
        self.step_dist = self.maxstep / 2

        # initial grid layout
        length = np.ceil(np.sqrt(len(self.bubbles)))
        grid = np.arange(length) * self.maxstep
        gx, gy = np.meshgrid(grid, grid)
        self.bubbles[:, 0] = gx.flatten()[:len(self.bubbles)]
        self.bubbles[:, 1] = gy.flatten()[:len(self.bubbles)]

        self.com = self.center_of_mass()

    def center_of_mass(self):
        return np.average(self.bubbles[:, :2], axis=0, weights=self.bubbles[:, 3])

    def center_distance(self, bubble, bubbles):
        return np.hypot(bubble[0] - bubbles[:, 0],
                        bubble[1] - bubbles[:, 1])

    def outline_distance(self, bubble, bubbles):
        center_distance = self.center_distance(bubble, bubbles)
        return center_distance - bubble[2] - bubbles[:, 2] - self.bubble_spacing

    def check_collisions(self, bubble, bubbles):
        distance = self.outline_distance(bubble, bubbles)
        return len(distance[distance < 0])

    def collides_with(self, bubble, bubbles):
        distance = self.outline_distance(bubble, bubbles)
        return np.argmin(distance, keepdims=True)

    def collapse(self, n_iterations=50):
        for _i in range(n_iterations):
            moves = 0
            for i in range(len(self.bubbles)):
                rest_bub = np.delete(self.bubbles, i, 0)
                dir_vec = self.com - self.bubbles[i, :2]
                dir_vec = dir_vec / np.sqrt(dir_vec.dot(dir_vec))
                new_point = self.bubbles[i, :2] + dir_vec * self.step_dist
                new_bubble = np.append(new_point, self.bubbles[i, 2:4])

                if not self.check_collisions(new_bubble, rest_bub):
                    self.bubbles[i, :] = new_bubble
                    self.com = self.center_of_mass()
                    moves += 1
                else:
                    for colliding in self.collides_with(new_bubble, rest_bub):
                        dir_vec = rest_bub[colliding, :2] - self.bubbles[i, :2]
                        dir_vec = dir_vec / np.sqrt(dir_vec.dot(dir_vec))
                        orth = np.array([dir_vec[1], -dir_vec[0]])
                        new_point1 = self.bubbles[i, :2] + orth * self.step_dist
                        new_point2 = self.bubbles[i, :2] - orth * self.step_dist
                        dist1 = self.center_distance(self.com, np.array([new_point1]))
                        dist2 = self.center_distance(self.com, np.array([new_point2]))
                        new_point = new_point1 if dist1 < dist2 else new_point2
                        new_bubble = np.append(new_point, self.bubbles[i, 2:4])
                        if not self.check_collisions(new_bubble, rest_bub):
                            self.bubbles[i, :] = new_bubble
                            self.com = self.center_of_mass()
            if moves / len(self.bubbles) < 0.1:
                self.step_dist = self.step_dist / 2
    def plot(self, ax, labels, colors, fontsize):
        """
        Draw the bubble plot with a static font size.

        Parameters
        ----------
        ax : matplotlib.axes.Axes
            The matplotlib axes to draw on.
        labels : list
            Labels of the bubbles.
        colors : list
            Colors of the bubbles.
        fontsize : int
            Font size of the labels.
        """
        for i in range(len(self.bubbles)):
            # Draw bubble
            circ = plt.Circle(
                self.bubbles[i, :2], self.bubbles[i, 2], color=colors[i]
            )
            ax.add_patch(circ)

            # Draw label with fixed font size
            ax.text(*self.bubbles[i, :2], labels[i],
                    horizontalalignment="center",
                    verticalalignment="center",
                    fontsize=fontsize)
# Take the 10 most frequent words
top10 = frequent_words_filtered.nlargest(50, "numbers")

# Convert to numpy arrays
labels = top10['words'].to_numpy()
areas = top10['numbers'].to_numpy()

# Create bubble chart
bubble_chart = BubbleChart(area=areas, bubble_spacing=0.2)
bubble_chart.collapse()

# Generate colors from a colormap
cmap = plt.cm.get_cmap("Pastel1")
colors = [cmap(i / len(labels)) for i in range(len(labels))]

# Shuffle colors randomly
random.shuffle(colors)


# Plot
fig, ax = plt.subplots(subplot_kw=dict(aspect="equal"))
bubble_chart.plot(ax, labels, colors, fontsize=4)
ax.axis("off")
ax.relim()
ax.autoscale_view()
ax.set_title("Top 50 Word Frequencies Before the Founding of the BSW")
plt.savefig('packed_bubble_chart_before.png', dpi=300)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17148\985674673.py:119: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("Pastel1")

# %% [markdown]
# creating WordClouds

# %%
wordcloud = WordCloud(background_color="white",
                      width=2500,
                      height=1000,
                      scale=2.0,
                      colormap= 'twilight',
                      min_font_size=6).fit_words(dict(Counter(filtered_keywords))).to_file(
                          'sahra_wagenknecht_before_word_cloud_test.png')

# %%
plt.figure(figsize=(15, 6))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
